# %% [markdown]
# # Задание:
#
# ### Дана функция:
# **_f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30_**
#
# 1. Определить корни;
# 2. Найти интервалы, на которых функция возрастает;
# 3. Найти интервалы, на которых функция убывает;
# 4. Построить график;
# 5. Вычислить вершину;
# 6. Определить промежутки, на котором f > 0;
# 7. Определить промежутки, на котором f < 0;

# %%
from sympy import *
import matplotlib.pyplot as plt
import matplotlib.collections as collections
import numpy as np

# %%
x = Symbol('x')

# %%
f = -12 * x ** 4 * sin(cos(x)) - 18  * x ** 3 + 5 * x ** 2 + 10 * x - 30
f
# Out:
# -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30

# %% [markdown]
# 1. Определить корни

# %%
f = -12 * x ** 4 * sin(cos(x)) - 18  * x ** 3 + 5 * x ** 2 + 10 * x - 30

# %%
ans = solveset(f)

# %%
ans
# Out:
# ConditionSet(x, Eq(-12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30, 0), Complexes)

# %% [markdown]
# Корни уравнения принадлежат множеству **{𝑥||𝑥∈ℂ∧−12x^4sin(cos(𝑥))−18x^3+5x^2+10x−30=0}**

# %% [markdown]
# 2. Найти интервалы, на которых функция возрастает;
# 3. Найти интервалы, на которых функция убывает;

# %% [markdown]
# Функция имеет бесконечное число отрезков, на которых она убывает и возрастает

# %% [markdown]
# 4. Построить график

# %%
x = np.arange(-50, 50, 0.0001)
x
# Out:
# array([-50.    , -49.9999, -49.9998, ...,  49.9997,  49.9998,  49.9999])

# %%
y = np.random.randint(-10, 10, size=(40))

# %%
f = -12 * x ** 4 * np.sin(np.cos(x)) - 18  * x ** 3 + 5 * x ** 2 + 10 * x - 30

# %%
plt.suptitle('График функции')
plt.plot(x, f, linewidth=1, color='red')
ax = plt.gca()
ax.axhline(y=0, color='k', linewidth = 0.5) 
plt.xlabel("X")
ax.axvline(x=0, color='k', linewidth = 0.5)
plt.ylabel("f(x)")
plt.minorticks_on()
plt.grid(which='major', color = 'grey', linewidth = 0.5)
plt.grid(which='minor',color = 'grey', linestyle = ':')
plt.show()

# %% [markdown]
# Для заданной функции определить корни, возрастание и убывние, найти вершину можно только на заданном интервале.
# Функция пересекает ось Y в точке -30
# _(f(0) = -30)_
#
# Например, для x∈{-2, -1, 0, 1, 2}:
#
# Есть два корня:
# x1 ≈ -1.33896663927711;
# X2 ≈ 2.27305684575625
#
# Функция убывает в интервале от -2 до ≈ 1.7
# Функция возрастает в интрвале от ≈ 1.7 до 2
#
# В интервале от -2 до 2 функция < 0
